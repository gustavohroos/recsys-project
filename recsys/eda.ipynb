# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
users = pd.read_csv('../data/users.csv')
print(users.head())
# Out:
#    UserID   Gender    Age  Married
# 0    1000        0  20-25        0
# 1    1001        1  20-25        0
# 2    1002        1  26-30        0
# 3    1003        0  26-30        1
# 4    1004        0  26-30        1

# %%
groups = pd.read_csv('../data/group.csv')
print(groups.head())
# Out:
#    GroupID  UserID
# 0      100    1305
# 1      100    1340
# 2      101    1244
# 3      101    1204
# 4      101    1361

# %%
ratings = pd.read_csv('../data/ratings.csv')
print(ratings.head())
# Out:
#    UserID  Item  Rating  App  Data  Ease Class Semester Lockdown
# 0    1173    28       5    4   4.0     4    DA     Fall      PRE
# 1    1173    41       5    4   4.0     4    DA     Fall      PRE
# 2    1173    61       4    4   4.0     4    DA     Fall      PRE
# 3    1173    22       1    1   2.0     2    DA     Fall      PRE
# 4    1173    27       1    1   2.0     2    DA     Fall      PRE

# %%
group_ratings = pd.read_csv('../data/group_ratings.csv')
print(group_ratings.head())
# Out:
#    GroupID  Item  Rating  App  Data  Ease Class Semester Lockdown
# 0      100     3       3    3     3     2    DB   Spring      PRE
# 1      100     5       3    3     3     2    DB   Spring      PRE
# 2      100     8       2    2     3     2    DB   Spring      PRE
# 3      100     9       2    2     3     2    DB   Spring      PRE
# 4      100    14       3    3     3     2    DB   Spring      PRE

# %%
items = pd.read_csv('../data/items.csv')
print(items.head())
# Out:
#    Item                                    Title  \
# 0     1                              E-Commerce
# 1     2                             News Website
# 2     3            Flight ticket purchase system
# 3     4              Inventory management system
# 4     5  Library (Book Rental and Return) System
#
#                                                  URL Descriptions
# 0      https://en.wikipedia.org/wiki/Online_shopping          NaN
# 1     https://en.wikipedia.org/wiki/Online_newspaper          NaN
# 2  https://en.wikipedia.org/wiki/Airline_reservat...          NaN
# 3  https://en.wikipedia.org/wiki/Inventory_manage...          NaN
# 4      https://en.wikipedia.org/wiki/Digital_library          NaN

# %%
len(items) + len(users)
# Out:
# 546
